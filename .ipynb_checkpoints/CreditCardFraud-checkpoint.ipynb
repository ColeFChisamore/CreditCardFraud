# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv")

# %%
# Separate the data into the credit card frauds and non-frauds
fraud = df[df["Class"] == 1]
real = df[df["Class"] == 0]
print(len(fraud)/len(df))
# Out:
# 0.001727485630620034

# %% [markdown]
# First we have to note that only a small fraction (<0.2%) of the total data points are frauds. This may make our model care less about detecting fraud, and will be dealt with later.

# %%
plt.xlim(0, 500)
sns.histplot(data=df, x="Amount", hue="Class", binwidth= 10, common_norm=False, stat="density")
plt.legend(labels=["Fraud", "Real"])
print("Amount Statistics for Fraudulent Cases:\n", fraud.Amount.describe(), "\n")
print("Amount Statistics for Non-Fraud Cases:\n", real.Amount.describe())
# Out:
# Amount Statistics for Fraudulent Cases:
#  count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64
#
# Amount Statistics for Non-Fraud Cases:
#  count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# From the statistics we can see that on average the fraudulent claims are higher than the real claims. The graph shows that both the real and fraudulent claims follow an exponential distribution, however the real claims follow the distribution a lot closer. The fraud claims have a larger tail than the real claims (especially peaking at around 100 and 320), again meaning that fraudulent claims tend go higher than real ones.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

## Get data into covariate matrix and response vector
x = df.drop('Class', axis = 'columns').values
y = df.Class.values

# then into training/testing
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=4)

# %%
## Train the model:
rfc = RandomForestClassifier(random_state=4)
rfc.fit(xTrain, yTrain)
# Out:
# RandomForestClassifier(random_state=4)

# %%
# Do predictions
yPred = rfc.predict(xTest)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, confusion_matrix, ConfusionMatrixDisplay

accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred)
recall = recall_score(yTest, yPred)
f1 = f1_score(yTest, yPred)
myStat = f1*0.4 + recall*0.6
print("Number of Claims:", yTest.shape[0], "\nPercent of Claims that are Valid:", 
      np.where(yTest==0)[0].size / yTest.size, "\nAccuracy:", accuracy, "\nPrecision:", precision, "\nRecall:", recall, "\nF1 Score:", f1)
# Out:
# Number of Claims: 56962
# Percent of Claims that are Valid: 0.9982268881008391
# Accuracy: 0.9995435553526912
# Precision: 0.9213483146067416
# Recall: 0.8118811881188119
# F1 Score: 0.8631578947368421

# %%
## Plotting a confusion matrix
cm = confusion_matrix(yTest, yPred)
cmd = ConfusionMatrixDisplay(cm, display_labels=["Real","Fraud"])
cmd.plot()

# %% [markdown]
# After training the random forest classifier model and using it on the test data to measure how well it performs, we find that it correctly predicts about 99.95% of the cases (accuracy). Furthermore when the model predicts fraud, it is correct in its prediction 92.13% of the time (precision). However when the claim is actually fraud, it only correctly identifies this 81.19% of the time (recall). This last statistic (recall) is the most important one for our situation, since we care most about detecting fraud with our model. Yet we could also consider the F1 score of 86.32%, which is a balance between the precision and the recall.
#
# Since the dataset has such a small number of fraudulent claims, it is difficult for the model to get a low recall without adjusting the sampling. I will attempt to try different ratios of real:fraud cases in sampling the X and Y for the training data, and see which ones give a good recall value without lowering precision or accuracy too far. I will do this by undersampling the real cases, while maintaining every fraud case.

# %%
ratios = []
precision = []
recall = []
f1 = []

yTrainFraud = yTrain[np.where(yTrain == 1)[0]]
yTrainValid = yTrain[np.where(yTrain == 0)[0]]
xTrainFraud = xTrain[np.where(yTrain == 1)[0]]
xTrainValid = xTrain[np.where(yTrain == 0)[0]]
maxInd = yTrainValid.shape[0]

# "rat" is part of the ratio between fraud and real claims (fraud:real == 1:rat)
rat = 1
while (rat <= 571):
    print("trying ratio 1:", rat)
    ratios.append(rat)
    sampleIndices = np.random.choice(maxInd, 391*rat, replace=False)
    # x2 and y2 are made up of all frauds and subset of reals
    yTrain2 = np.concatenate((yTrainFraud, yTrainValid[sampleIndices]))
    xTrain2 = np.concatenate((xTrainFraud, xTrainValid[sampleIndices]))
    # train new tree
    rfc2 = RandomForestClassifier(random_state=4, n_jobs=-1)
    rfc2.fit(xTrain2, yTrain2)
    name = "rfcModel" + str(rat)
    # test on existing test data
    yPred2 = rfc2.predict(xTest)
    precision.append(precision_score(yTest, yPred2))
    recall.append(recall_score(yTest, yPred2))
    f1.append(f1_score(yTest, yPred2))
    rat = rat + 20
# Out:
# trying ratio 1: 1
# trying ratio 1: 21
# trying ratio 1: 41
# trying ratio 1: 61
# trying ratio 1: 81
# trying ratio 1: 101
# trying ratio 1: 121
# trying ratio 1: 141
# trying ratio 1: 161
# trying ratio 1: 181
# trying ratio 1: 201
# trying ratio 1: 221
# trying ratio 1: 241
# trying ratio 1: 261
# trying ratio 1: 281
# trying ratio 1: 301
# trying ratio 1: 321
# trying ratio 1: 341
# trying ratio 1: 361
# trying ratio 1: 381
# trying ratio 1: 401
# trying ratio 1: 421
# trying ratio 1: 441
# trying ratio 1: 461
# trying ratio 1: 481
# trying ratio 1: 501
# trying ratio 1: 521
# trying ratio 1: 541
# trying ratio 1: 561

# %%
statsData = {'Real:Fraud Claims Ratio': ratios,
            'Precision': precision,
            'Recall': recall,
            'F1': f1}
statsDf = pd.DataFrame(data = statsData)

# %%
statsDfLong = pd.melt(statsDf, "Real:Fraud Claims Ratio")
plot = sns.lineplot(data=statsDfLong, x='Real:Fraud Claims Ratio', y='value', hue='variable')
plt.show()

# %% [markdown]
# As expected we see that the recall statistic is quite good at lower ratios since the model is tailored to the higher fraction of fraudulent claims, which also makes the precision much worse. I will redo the ratios from 100:1 to maximum again more precisely to getter finer results for this range, since the range from 1:1 to 100:1 doesn't provide good enough statistics anyways.

# %%
ratios = []
precision = []
recall = []
f1 = []

yTrainFraud = yTrain[np.where(yTrain == 1)[0]]
yTrainValid = yTrain[np.where(yTrain == 0)[0]]
xTrainFraud = xTrain[np.where(yTrain == 1)[0]]
xTrainValid = xTrain[np.where(yTrain == 0)[0]]
maxInd = yTrainValid.shape[0]

# "rat" is part of the ratio between fraud and real claims (fraud:real == 1:rat)
for rat in range(80,300,2):
    print("trying ratio 1:", rat)
    ratios.append(rat)
    sampleIndices = np.random.choice(maxInd, 391*rat, replace=False)
    # x2 and y2 are made up of all frauds and subset of reals
    yTrain2 = np.concatenate((yTrainFraud, yTrainValid[sampleIndices]))
    xTrain2 = np.concatenate((xTrainFraud, xTrainValid[sampleIndices]))
    # train new tree
    rfc2 = RandomForestClassifier(random_state=4, n_jobs=-1)
    rfc2.fit(xTrain2, yTrain2)
    name = "rfcModel" + str(rat)
    # test on existing test data
    yPred2 = rfc2.predict(xTest)
    precision.append(precision_score(yTest, yPred2))
    recall.append(recall_score(yTest, yPred2))
    f1.append(f1_score(yTest, yPred2))
# Out:
# trying ratio 1: 80
# trying ratio 1: 82
# trying ratio 1: 84
# trying ratio 1: 86
# trying ratio 1: 88
# trying ratio 1: 90
# trying ratio 1: 92
# trying ratio 1: 94
# trying ratio 1: 96
# trying ratio 1: 98
# trying ratio 1: 100
# trying ratio 1: 102
# trying ratio 1: 104
# trying ratio 1: 106
# trying ratio 1: 108
# trying ratio 1: 110
# trying ratio 1: 112
# trying ratio 1: 114
# trying ratio 1: 116
# trying ratio 1: 118
# trying ratio 1: 120
# trying ratio 1: 122
# trying ratio 1: 124
# trying ratio 1: 126
# trying ratio 1: 128
# trying ratio 1: 130
# trying ratio 1: 132
# trying ratio 1: 134
# trying ratio 1: 136
# trying ratio 1: 138
# trying ratio 1: 140
# trying ratio 1: 142
# trying ratio 1: 144
# trying ratio 1: 146
# trying ratio 1: 148
# trying ratio 1: 150
# trying ratio 1: 152
# trying ratio 1: 154
# trying ratio 1: 156
# trying ratio 1: 158
# trying ratio 1: 160
# trying ratio 1: 162
# trying ratio 1: 164
# trying ratio 1: 166
# trying ratio 1: 168
# trying ratio 1: 170
# trying ratio 1: 172
# trying ratio 1: 174
# trying ratio 1: 176
# trying ratio 1: 178
# trying ratio 1: 180
# trying ratio 1: 182
# trying ratio 1: 184
# trying ratio 1: 186
# trying ratio 1: 188
# trying ratio 1: 190
# trying ratio 1: 192
# trying ratio 1: 194
# trying ratio 1: 196
# trying ratio 1: 198
# trying ratio 1: 200
# trying ratio 1: 202
# trying ratio 1: 204
# trying ratio 1: 206
# trying ratio 1: 208
# trying ratio 1: 210
# trying ratio 1: 212
# trying ratio 1: 214
# trying ratio 1: 216
# trying ratio 1: 218
# trying ratio 1: 220
# trying ratio 1: 222
# trying ratio 1: 224
# trying ratio 1: 226
# trying ratio 1: 228
# trying ratio 1: 230
# trying ratio 1: 232
# trying ratio 1: 234
# trying ratio 1: 236
# trying ratio 1: 238
# trying ratio 1: 240
# trying ratio 1: 242
# trying ratio 1: 244
# trying ratio 1: 246
# trying ratio 1: 248
# trying ratio 1: 250
# trying ratio 1: 252
# trying ratio 1: 254
# trying ratio 1: 256
# trying ratio 1: 258
# trying ratio 1: 260
# trying ratio 1: 262
# trying ratio 1: 264
# trying ratio 1: 266
# trying ratio 1: 268
# trying ratio 1: 270
# trying ratio 1: 272
# trying ratio 1: 274
# trying ratio 1: 276
# trying ratio 1: 278
# trying ratio 1: 280
# trying ratio 1: 282
# trying ratio 1: 284
# trying ratio 1: 286
# trying ratio 1: 288
# trying ratio 1: 290
# trying ratio 1: 292
# trying ratio 1: 294
# trying ratio 1: 296
# trying ratio 1: 298

# %%
statsData = {'Real:Fraud Claims Ratio': ratios,
            'Precision': precision,
            'Recall': recall,
            'F1': f1}
statsDf = pd.DataFrame(data = statsData)
statsDf.to_csv("statsDf.csv", index=False)

# %%
statsDf = pd.read_csv("statsDf.csv")

# %%
statsDf
# Out:
#      Real:Fraud Claims Ratio  Precision    Recall        F1
# 0                         80   0.833333  0.891089  0.861244
# 1                         82   0.855769  0.881188  0.868293
# 2                         84   0.873786  0.891089  0.882353
# 3                         86   0.847619  0.881188  0.864078
# 4                         88   0.855769  0.881188  0.868293
# ..                       ...        ...       ...       ...
# 105                      290   0.905263  0.851485  0.877551
# 106                      292   0.924731  0.851485  0.886598
# 107                      294   0.913978  0.841584  0.876289
# 108                      296   0.933333  0.831683  0.879581
# 109                      298   0.905263  0.851485  0.877551
#
# [110 rows x 4 columns]

# %%
rollingSDF = pd.DataFrame()
rollingSDF['Real:Fraud Claims Ratio'] = statsDf['Real:Fraud Claims Ratio']
rollingSDF['Precision'] = statsDf['Precision'].rolling(window=9,center=True).mean()
rollingSDF['Recall'] = statsDf['Recall'].rolling(window=9,center=True).mean()
rollingSDF['F1'] = statsDf['F1'].rolling(window=9,center=True).mean()
rollingSDF_Long = pd.melt(rollingSDF, "Real:Fraud Claims Ratio")
plot = sns.lineplot(data=rollingSDF_Long, x='Real:Fraud Claims Ratio', y='value', hue='variable')
plt.show()

# %%
# where do various stats reach their peak?
print("Recall maximum at ratio ", rollingSDF['Recall'].idxmax() * 2 + 80, ":1")
print("F1 maximum at ratio ", rollingSDF['F1'].idxmax() * 2 + 80, ":1")
# Out:
# Recall maximum at ratio  88 :1
# F1 maximum at ratio  286 :1

# %%
sampleIndices = np.random.choice(maxInd, 391*88, replace=False)
# x2 and y2 are made up of all frauds and subset of reals
yTrain88 = np.concatenate((yTrainFraud, yTrainValid[sampleIndices]))
xTrain88 = np.concatenate((xTrainFraud, xTrainValid[sampleIndices]))
# train new tree
rfc88 = RandomForestClassifier(random_state=4, n_jobs=-1)
rfc88.fit(xTrain88, yTrain88)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=4)

# %%
sampleIndices = np.random.choice(maxInd, 391*286, replace=False)
# x2 and y2 are made up of all frauds and subset of reals
yTrain286 = np.concatenate((yTrainFraud, yTrainValid[sampleIndices]))
xTrain286 = np.concatenate((xTrainFraud, xTrainValid[sampleIndices]))
# train new tree
rfc286 = RandomForestClassifier(random_state=4, n_jobs=-1)
rfc286.fit(xTrain286, yTrain286)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=4)

# %%
rfcFullpred = rfc.predict(xTest)
rfc88pred = rfc88.predict(xTest)
rfc286pred = rfc286.predict(xTest)
predictions = [rfcFullpred, rfc88pred, rfc286pred]

# %%
compareDF = pd.DataFrame({"Statistic": ["Accuracy","Precision","Recall","F1"]})
names = ["Full", "88", "286"]

for i, p in enumerate(predictions):
    Acc = accuracy_score(yTest,p)
    Prec = precision_score(yTest,p)
    Rec = recall_score(yTest,p)
    Fone = f1_score(yTest,p)
    compareDF[names[i]] = [Acc, Prec, Rec, Fone]

# %%
compareDF
# Out:
#    Statistic      Full        88       286
# 0   Accuracy  0.999544  0.999491  0.999544
# 1  Precision  0.921348  0.833333  0.894737
# 2     Recall  0.811881  0.891089  0.841584
# 3         F1  0.863158  0.861244  0.867347

# %% [markdown]
# From this graph we can see clearly that undersampling has benefitted the model. Unfortunately we have not improved the recall %, but we have increased the precision of our model (despite training it on less data!).

# %%
cdfLong = pd.melt(compareDF, 'Statistic')
sns.barplot(data=cdfLong, x='Statistic', y='value', hue='variable')
# Out:
# <Axes: xlabel='Statistic', ylabel='value'>

# %%
## Plotting a confusion matrix
cm = confusion_matrix(yTest, predictions[1])
cmd = ConfusionMatrixDisplay(cm, display_labels=["Real","Fraud"])
cmd.plot()

# %%
## Plotting a confusion matrix
cm = confusion_matrix(yTest, predictions[2])
cmd = ConfusionMatrixDisplay(cm, display_labels=["Real","Fraud"])
cmd.plot()
